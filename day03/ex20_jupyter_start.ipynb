# %% [markdown]
# ## 주피터 노트북 시작
#
# - 마크다운 쉘은 일반 md 파일에서 작성하는 것과 동일함
# - [네이버](https://www.naver.com)
#
# -주피터 노트북의 경로는 해당위치부터 시작
#     ![이미지](./![image-1.png](attachment:image-1.png))

# %%
print('Hello,Jupyter')
# Out:
# Hello,Jupyter

# %%
num =int(input('정수 입력>'))

# %%
print(num)
# Out:
# 10

# %%
num
# Out:
# 10

# %%
# print() 하뭇와 변수명만 적는게 모두 출력
num +10
num *10
# Out:
# 100

# %% [markdown]
# - print () 함수를 사용하지 않으면 가장 마지막의 변수만 출력됨
# -모두 출력하고자 하면 모두 print() 함수를 쓸것

# %%
print(num)
print(num+10)
print(num*10)
# Out:
# 10
# 20
# 100

# %% [markdown]
# ## 분석용 기초 이론
#
# ### 기존의 리스트 사용법을 좀 더 간결하고 효율적으로 사용하기 위해서
#
# #기존방식
# result1 =[]
# for i in range(10):
#     result1.append(i)

# %%
# 기존방식
result1.clear()

for i in range(2,100,2):
    result1.append(i)
